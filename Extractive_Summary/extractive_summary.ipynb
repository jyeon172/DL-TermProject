# %% [markdown]
# #Install libraries

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip3 install konlpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 64.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 465.3/465.3 kB 48.0 MB/s eta 0:00:00
# ...

# %%
# !sudo apt-get update
# Out:
# Get:1 http://security.ubuntu.com/ubuntu focal-security InRelease [114 kB]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu focal-cran40/ InRelease [3,622 B]
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu focal InRelease
# Get:5 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu focal InRelease [18.1 kB]
# Get:6 http://archive.ubuntu.com/ubuntu focal-updates InRelease [114 kB]
# Get:7 http://security.ubuntu.com/ubuntu focal-security/main amd64 Packages [2,726 kB]
# Hit:8 http://ppa.launchpad.net/cran/libgit2/ubuntu focal InRelease
# Get:9 http://security.ubuntu.com/ubuntu focal-security/universe amd64 Packages [1,052 kB]
# Get:10 http://archive.ubuntu.com/ubuntu focal-backports InRelease [108 kB]
# Hit:11 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu focal InRelease
# Hit:12 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu focal InRelease
# ...

# %%
# !sudo apt-get install curl git
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# curl is already the newest version (7.68.0-1ubuntu2.18).
# git is already the newest version (1:2.25.1-1ubuntu3.11).
# 0 upgraded, 0 newly installed, 0 to remove and 34 not upgraded.

# %%
# !pip3 install multiprocess
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 3.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 11.6 MB/s eta 0:00:00
# ...

# %%
# !pip3 install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 50.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 25.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 74.9 MB/s eta 0:00:00
# ...

# %%
# !pip install pyrouge --upgrade
# !pip install https://github.com/bheinzerling/pyrouge/archive/master.zip
# !pip install pyrouge
# !pip show pyrouge
# !git clone https://github.com/andersjo/pyrouge.git
from pyrouge import Rouge155
# !pyrouge_set_rouge_path '/content/pyrouge/tools/ROUGE-1.5.5'
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.5/60.5 kB 2.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pyrouge: filename=pyrouge-0.1.3-py3-none-any.whl size=191605 sha256=2315e8a19d9e4f655b1e3c88f704066ea116ebd8530fb8a96fccf67572e46891
#   Stored in directory: /root/.cache/pip/wheels/9a/67/12/c5dd8ef8b4152bb8789eafd2a74a734e2dc7bb9eae02b768e7
# Successfully built pyrouge
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      - 202.3 kB 4.0 MB/s 0:00:00
#   Preparing metadata (setup.py) ... done
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Name: pyrouge
# Version: 0.1.3
# Summary: A Python wrapper for the ROUGE summarization evaluation package.
# Home-page: https://github.com/noutenki/pyrouge
# ...

# %%
# !sudo apt-get install libxml-parser-perl
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libauthen-sasl-perl libdata-dump-perl libencode-locale-perl
#   libfile-listing-perl libfont-afm-perl libhtml-form-perl libhtml-format-perl
#   libhtml-parser-perl libhtml-tagset-perl libhtml-tree-perl
#   libhttp-cookies-perl libhttp-daemon-perl libhttp-date-perl
#   libhttp-message-perl libhttp-negotiate-perl libio-html-perl
#   libio-socket-ssl-perl liblwp-mediatypes-perl liblwp-protocol-https-perl
#   libmailtools-perl libnet-http-perl libnet-smtp-ssl-perl libnet-ssleay-perl
#   libtry-tiny-perl liburi-perl libwww-perl libwww-robotrules-perl netbase
#   perl-openssl-defaults
# Suggested packages:
#   libdigest-hmac-perl libgssapi-perl libcrypt-ssleay-perl libauthen-ntlm-perl
# The following NEW packages will be installed:
#   libauthen-sasl-perl libdata-dump-perl libencode-locale-perl
# ...

# %%
# %%shell
# cd pyrouge/tools/ROUGE-1.5.5/data
# rm WordNet-2.0.exc.db # only if exist
# cd WordNet-2.0-Exceptions
# rm WordNet-2.0.exc.db # only if exist
#
# ./buildExeptionDB.pl . exc WordNet-2.0.exc.db
# cd ../
# ln -s WordNet-2.0-Exceptions/WordNet-2.0.exc.db WordNet-2.0.exc.db
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# impanelling
# impelled
# impelling
# implied
# inbred
# incurred
# incurring
# indemnified
# indwelt
# inferred
# inferring
# initialled
# initialling
# inlaid
# insetting
# inspanned
# inspanning
# installed
# installing
# intensified
# interbred
# intercropped
# intercropping
# intercutting
# interlaid
# interlapped
# interlapping
# intermarried
# intermitted
# intermitting
# interpled
# interred
# interring
# interstratified
# interwove
# interwoven
# intromitted
# intromitting
# inwove
# inwoven
# inwrapped
# inwrapping
# is
# jabbed
# jabbing
# jagged
# jagging
# jammed
# jamming
# japanned
# japanning
# jarred
# jarring
# jellied
# jellified
# jemmied
# jerry-built
# jetted
# jetting
# jewelled
# jewelling
# jibbed
# jibbing
# jigged
# jigging
# jimmied
# jitterbugged
# jitterbugging
# jobbed
# jobbing
# jog-trotted
# jog-trotting
# jogged
# jogging
# joined_battle
# joined_forces
# joining_battle
# joining_forces
# joins_battle
# ...

# %%
# !pip3 install tensorboardX
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 3.9 MB/s eta 0:00:00
# ...

# %%
# !rm -r /content/SRC
# Out:
# rm: cannot remove '/content/SRC': No such file or directory

# %%
# !cp -r /content/drive/MyDrive/Gachon_University/2023-1/DeepLearning/ActiveLearning/extractive_summary/SRC .

# %% [markdown]
# # Import libraries

# %%
import os
import json
from tqdm import tqdm
import re
import easydict

# %% [markdown]
# # Data Preprocessing

# %%
os.getcwd()
# Out:
# '/content'

# %%
DATAPATH = "/content/drive/MyDrive/Gachon_University/2023-1/DeepLearning/ActiveLearning/extractive_summary/DATA/raw_data/train"
filenames = [x for x in os.listdir (DATAPATH) if x.endswith('json')]
filenames.sort()
filenames
# Out:
# ['train_original_law.json',
#  'train_original_news.json',
#  'train_original_opinion.json']

# %%
file = filenames[0]
filelocation = os.path.join(DATAPATH, file)

with open(filelocation, 'r') as json_file:
  data = json.load(json_file)['documents']

# %%
data[0]
# Out:
# {'id': '100004',
#  'category': '일반행정',
#  'size': 'small',
#  'char_count': 377,
#  'publish_date': '19841226',
#  'title': '부당노동행위구제재심판정취소',
#  'text': [[{'index': 0,
#     'sentence': '원고가 소속회사의 노동조합에서 분규가 발생하자 노조활동을 구실로 정상적인 근무를 해태하고,',
#     'highlight_indices': ''},
#    {'index': 1, 'sentence': '노조조합장이 사임한 경우,', 'highlight_indices': ''},
#    {'index': 2,
#     'sentence': '노동조합규약에 동 조합장의 직무를 대행할 자를 규정해 두고 있음에도 원고 자신이 주동하여 노조자치수습대책위원회를 구성하여 그 위원장으로 피선되어 근무시간중에도 노조활동을 벌여 운수업체인 소속회사의 업무에 지장을 초래하고',
#     'highlight_indices': '8,9;68,69'},
#    {'index': 3,
#     'sentence': '종업원들에게도 나쁜 영향을 끼쳐 소속회사가 취업규칙을 위반하고',
#     'highlight_indices': ''},
#    {'index': 4,
#     'sentence': '고의로 회사업무능률을 저해하였으며 회사업무상의 지휘명령에 위반하였음을 이유로 원고를 징계해고 하였다면,',
#     'highlight_indices': '0,3'},
#    {'index': 5,
#     'sentence': '이는 원고의 노동조합 활동과는 관계없이 회사취업규칙에 의하여 사내질서를 유지하기 위한 사용자 고유의 징계권에 기하여 이루어진 정당한 징계권의 행사로 보아야 한다.',
#     'highlight_indices': '17,21'}]],
#  'annotator_id': 3783,
# ...

# %% [markdown]
# ### Train dataset

# %%
DATAPATH = "/content/drive/MyDrive/Gachon_University/2023-1/DeepLearning/ActiveLearning/extractive_summary/DATA/raw_data/train"
filenames = [x for x in os.listdir (DATAPATH) if x.endswith('json')]
filenames.sort()
filenames
# Out:
# ['train_original_law.json',
#  'train_original_news.json',
#  'train_original_opinion.json']

# %%
list_dic = []

for file in filenames:
  filelocation = os.path.join(DATAPATH, file)

  with open(filelocation, 'r') as json_file:
    data = json.load(json_file)['documents']

    for x in tqdm (range(len(data))):
      text = data[x]['text']
      text = str(text).replace('"', "'")

      extractive = data[x]['extractive']
      for index, value in enumerate(extractive):
        if value == None:
          extractive[index] = 0

      p = re.compile('(?<=sentence\'\: \')(.*?)(?=\'highlight_indices)')
      texts = p.findall(text)

      sentences = []
      for t in texts:
        sentence = t[:-3]
        sentences.append(sentence)

      mydict = {}
      mydict['text'] = sentences
      mydict['extractive'] = extractive
      list_dic.append(mydict)
# Out:
# ...
# 100%|██████████| 56760/56760 [00:07<00:00, 7828.09it/s]

# %%
with open("/content/drive/MyDrive/Gachon_University/2023-1/DeepLearning/ActiveLearning/extractive_summary/DATA/raw_data/train.json", 'w') as fh:
  json.dump(list_dic, fh)

# %%
with open("/content/drive/MyDrive/Gachon_University/2023-1/DeepLearning/ActiveLearning/extractive_summary/DATA/raw_data/train.json", 'r') as f:
  data = json.load(f)

  print(len(data))
# Out:
# 325072

# %%
def list_chunk(lst, n):
    return [lst[i:i+n] for i in range(0, len(lst), n)]

data_chunked = list_chunk(data, 32507) ## 전체 데이터를 10개로 분할

for i, d in enumerate(data_chunked):
  with open("/content/drive/MyDrive/Gachon_University/2023-1/DeepLearning/ActiveLearning/extractive_summary/DATA/raw_data/train.{}.json".format(i), 'w') as fh:
    json.dump(d, fh)

# %% [markdown]
# ### Valid dataset

# %%
DATAPATH = "/content/drive/MyDrive/Gachon_University/2023-1/DeepLearning/ActiveLearning/extractive_summary/DATA/raw_data/valid"
filenames = [x for x in os.listdir (DATAPATH) if x.endswith('json')]
filenames.sort()
filenames
# Out:
# ['valid_original_law.json',
#  'valid_original_news.json',
#  'valid_original_opinion.json']

# %%
list_dic = []

for file in filenames:
  filelocation = os.path.join(DATAPATH, file)

  with open(filelocation, 'r') as json_file:
    data = json.load(json_file)['documents']

    for x in tqdm (range(len(data))):
      text = data[x]['text']
      text = str(text).replace('"', "'")

      extractive = data[x]['extractive']
      for index, value in enumerate(extractive):
        if value == None:
          extractive[index] = 0

      p = re.compile('(?<=sentence\'\: \')(.*?)(?=\'highlight_indices)')
      texts = p.findall(text)

      sentences = []
      for t in texts:
        sentence = t[:-3]
        sentences.append(sentence)

      mydict = {}
      mydict['text'] = sentences
      mydict['extractive'] = extractive
      list_dic.append(mydict)
# Out:
# ...
# 100%|██████████| 7008/7008 [00:00<00:00, 9419.86it/s]

# %%
with open("/content/drive/MyDrive/Gachon_University/2023-1/DeepLearning/ActiveLearning/extractive_summary/DATA/raw_data/valid.json", 'w') as fh:
  json.dump(list_dic, fh)

# %% [markdown]
# ## tokenizing

# %%
 ! git clone https://github.com/SOMJANG/Mecab-ko-for-Google-Colab.git
# Out:
# Cloning into 'Mecab-ko-for-Google-Colab'...
# remote: Enumerating objects: 122, done.
# remote: Counting objects: 100% (31/31), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 122 (delta 15), reused 10 (delta 3), pack-reused 91
# Receiving objects: 100% (122/122), 1.27 MiB | 29.61 MiB/s, done.
# Resolving deltas: 100% (54/54), done.

# %%
 cd Mecab-ko-for-Google-Colab
# Out:
# /content/Mecab-ko-for-Google-Colab

# %%
ls
# Out:
# images/                                    LICENSE
# install_mecab-ko_on_colab190912.sh         README.md
# install_mecab-ko_on_colab_light_220429.sh

# %%
 # !bash install_mecab-ko_on_colab_light_220429.sh
# Out:
# Installing konlpy.....
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Done
# Installing mecab-0.996-ko-0.9.2.tar.gz.....
# ...
# from https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# --2023-05-27 10:42:25--  https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# Resolving bitbucket.org (bitbucket.org)... 104.192.141.1, 2406:da00:ff00::6b17:d1f5, 2406:da00:ff00::22cd:e0db, ...
# Connecting to bitbucket.org (bitbucket.org)|104.192.141.1|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
from konlpy.tag import Mecab
mecab = Mecab()

# %% [markdown]
# #### Train data

# %%
DATAPATH = "/content/drive/MyDrive/Gachon_University/2023-1/DeepLearning/ActiveLearning/extractive_summary/DATA/raw_data"
filenames = [x for x in os.listdir (DATAPATH) if 'train' in x and x.endswith('json')]
filenames
# Out:
# ['train.json',
#  'train.0.json',
#  'train.1.json',
#  'train.2.json',
#  'train.3.json',
#  'train.4.json',
#  'train.5.json',
#  'train.6.json',
#  'train.7.json',
#  'train.8.json',
#  'train.9.json',
#  'train.10.json']

# %%
trainfiles = []
for f in filenames[1:-1]:
  trainfiles.append(f[:-5])

# %%
for set_name in trainfiles:
  print("Processing ... ", set_name)

  with open("/content/drive/MyDrive/Gachon_University/2023-1/DeepLearning/ActiveLearning/extractive_summary/DATA/raw_data/{}.json".format(set_name), 'r') as f:
    data = json.load(f)

    list_dic = []
    for x in tqdm(range(len(data))):
      text = data[x]['text']
      extractive = data[x]['extractive']

      sentences = []
      for sentence in text:
        sentence_morph = ' '.join(mecab.morphs(sentence))
        sentences.append(sentence_morph)

      extractives = []
      for e in extractive:
        extractives.append(sentences[e])

      src = [i.split(' ') for i in sentences]
      tgt = [i.split(' ') for i in extractives]

      mydict = {}
      mydict['src'] = src
      mydict['tgt'] = tgt
      list_dic.append(mydict)

    jsonfilelocation = '/content/drive/MyDrive/Gachon_University/2023-1/DeepLearning/ActiveLearning/extractive_summary/DATA/json_data/' + 'train'
    os.makedirs(jsonfilelocation, exist_ok=True)

    temp = []
    DATA_PER_FILE = 50

    for i,a in enumerate(tqdm(list_dic)):
      if (i+1)%DATA_PER_FILE!=0:
        temp.append(a)
      else:
        temp.append(a)
        filename = 'korean.'+ set_name + '.' + str(i//DATA_PER_FILE)+'.json'
        with open(os.path.join(jsonfilelocation, filename), "w", encoding='utf-8') as json_file:
          json.dump(temp, json_file, ensure_ascii=False)
          temp = []

      #마지막에 남은 데이터 있으면 추가로 append
      if len(temp) != 0:
        filename = 'korean.'+ set_name + '.' + str(i//DATA_PER_FILE + 1)+'.json'
        with open(os.path.join(jsonfilelocation, filename), "w", encoding='utf-8') as json_file:
          json.dump(temp, json_file, ensure_ascii=False)
# Out:
# Processing ...  train.0
# ...
# 100%|██████████| 32507/32507 [15:00<00:00, 36.09it/s]
# Processing ...  train.1
# ...
# 100%|██████████| 32507/32507 [14:43<00:00, 36.81it/s]
# Processing ...  train.2
# ...
# 100%|██████████| 32507/32507 [14:37<00:00, 37.03it/s]
# Processing ...  train.3
# ...
# 100%|██████████| 32507/32507 [14:43<00:00, 36.79it/s]
# Processing ...  train.4
# ...
# 100%|██████████| 32507/32507 [14:36<00:00, 37.11it/s]
# Processing ...  train.5
# ...
# 100%|██████████| 32507/32507 [14:38<00:00, 37.00it/s]
# Processing ...  train.6
# ...
# 100%|██████████| 32507/32507 [14:32<00:00, 37.25it/s]
# Processing ...  train.7
# ...
# 100%|██████████| 32507/32507 [14:15<00:00, 38.00it/s]
# Processing ...  train.8
# ...
# 100%|██████████| 32507/32507 [14:57<00:00, 36.22it/s]
# Processing ...  train.9
# ...
# 100%|██████████| 32507/32507 [14:58<00:00, 36.18it/s]

# %% [markdown]
# #### Valid data

# %%
set_name = 'valid'

with open("/content/drive/MyDrive/Gachon_University/2023-1/DeepLearning/ActiveLearning/extractive_summary/DATA/raw_data/{}.json".format(set_name), 'r') as f:
  data = json.load(f)

  list_dic = []
  for x in tqdm(range(len(data))):
    text = data[x]['text']
    extractive = data[x]['extractive']

    sentences = []
    for sentence in text:
      sentence_morph = ' '.join(mecab.morphs(sentence))
      sentences.append(sentence_morph)

    extractives = []
    for e in extractive:
      extractives.append(sentences[e])

    src = [i.split(' ') for i in sentences]
    tgt = [i.split(' ') for i in extractives]

    mydict = {}
    mydict['src'] = src
    mydict['tgt'] = tgt
    list_dic.append(mydict)

  jsonfilelocation = '/content/drive/MyDrive/Gachon_University/2023-1/DeepLearning/ActiveLearning/extractive_summary/DATA/json_data/' + set_name
  os.makedirs(jsonfilelocation, exist_ok=True)

  temp = []
  DATA_PER_FILE = 50

  for i,a in enumerate(tqdm(list_dic)):
    if (i+1)%DATA_PER_FILE!=0:
      temp.append(a)
    else:
      temp.append(a)
      filename = 'korean.'+ set_name + '.' + str(i//DATA_PER_FILE)+'.json'
      with open(os.path.join(jsonfilelocation, filename), "w", encoding='utf-8') as json_file:
        json.dump(temp, json_file, ensure_ascii=False)
        temp = []

    #마지막에 남은 데이터 있으면 추가로 append
    if len(temp) != 0:
      filename = 'korean.'+ set_name + '.' + str(i//DATA_PER_FILE + 1)+'.json'
      with open(os.path.join(jsonfilelocation, filename), "w", encoding='utf-8') as json_file:
        json.dump(temp, json_file, ensure_ascii=False)
# Out:
# ...
# 100%|██████████| 40134/40134 [18:02<00:00, 37.07it/s]

# %% [markdown]
# ### BERT feature

# %%
import glob
from os.path import join as pjoin

from multiprocess import Pool
from SRC.prepro.data_builder import _format_to_bert

def format_to_bert(args):
    if (args.dataset != ''):
        datasets = args.dataset
    else:
        datasets = ['train', 'valid', 'test']
    for corpus_type in datasets:
        a_lst = []
        for json_f in glob.glob(pjoin(args.raw_path, corpus_type, '*' + corpus_type + '.*.json')):
            real_name = json_f.split('/')[-1]
            a_lst.append((json_f, args, pjoin(args.save_path, real_name.replace('json', 'bert.pt'))))
        # print(a_lst)
        pool = Pool(args.n_cpus)
        for d in pool.imap(_format_to_bert, a_lst):
            pass

        pool.close()
        pool.join()

# %% [markdown]
# #### Train data

# %%
set_name = 'train'

bertfilelocation = '/content/drive/MyDrive/Gachon_University/2023-1/DeepLearning/ActiveLearning/extractive_summary/DATA/bert_data/' + set_name
os.makedirs(bertfilelocation, exist_ok=True)

args = easydict.EasyDict({
  "dataset": [set_name], 
  "raw_path": "/content/drive/MyDrive/Gachon_University/2023-1/DeepLearning/ActiveLearning/extractive_summary/DATA/json_data/",
  "save_path": bertfilelocation,
  "n_cpus":4,
  "oracle_mode": "greedy",
  "min_src_ntokens": 5,
  "max_src_ntokens": 200,
  "min_nsents": 3,
  "max_nsents": 100,
})

format_to_bert(args)

# %% [markdown]
# #### Valid data

# %%
set_name = 'valid'

bertfilelocation = '/content/drive/MyDrive/Gachon_University/2023-1/DeepLearning/ActiveLearning/extractive_summary/DATA/bert_data/' + set_name
os.makedirs(bertfilelocation, exist_ok=True)

args = easydict.EasyDict({
  "dataset": [set_name], 
  "raw_path": "/content/drive/MyDrive/Gachon_University/2023-1/DeepLearning/ActiveLearning/extractive_summary/DATA/json_data/",
  "save_path": bertfilelocation,
  "n_cpus":4,
  "oracle_mode": "greedy",
  "min_src_ntokens": 5,
  "max_src_ntokens": 200,
  "min_nsents": 3,
  "max_nsents": 100,
})

format_to_bert(args)

# %% [markdown]
# # Modeling

# %% [markdown]
# ## Training

# %% [markdown]
# ### Hyperparameter
#   - model_path (Path): Fine-tuning한 모델이 저장되는 경로
#   - result_path (Path): 평가 시 추론 결과(candidate)와 정답(gold)이 저장되는 경로
#   - temp_dir (Path): 평가 시 ROUGE SCORE 결과가 저장되는 경로
#   - log_file (Path): 로그 파일이 저장되는 경로
#   - train_from (Path): 학습하고자 하는 체크포인트(pt)가 있을 경우 설정하는 경로
#   - bert_data_path (Path): 학습에 사용할 Bert Data(.pt)를 설정하는 경로
#
#   - batch_size (int): A Batch Size (default=1000)
#   - use_interval (bool): 학습 시 문서 내에서 여러 문장을 구별하기 위해 Interval Segment Embeddings를 사용하는 지의 여부 (default=True)
#   - hidden_size (int): Transformer Hidden Size (default=128)
#   - ff_size (int): Feed-forward Filter Size (default=2048)
#   - heads (int): Transformer Head 개수 (default=8)
#   - inter_layers (int): Transformer Inter Layer 개수 (default=2)
#   - rnn_size (int): Encoder RNN RNN Size(default=512)
#   - train_steps(int): 학습할 Step 수
#
#   - param_init (float): (default=0)
#   - param_init_glorot (bool): (default=True)
#   - dropout (float): Dropout (default=0.1)
#   - optim (str): Optimizer (default='adam')
#   - lr (float): Learning Rate (default=2e-3)
#   - beta1 (float): Adam Optimizer 관련 Hyper Parameter (default= 0.9)
#   - beta2 (float): Adam Optimizer 관련 Hyper Parameter (default=0.999)
#   - decay_method (str): Weight Decay (default='noam')
#   - warmup_steps (int): Warm-up Steps (default=6000)
#   - max_grad_norm (float): Max Gradient Noam (default=0)
#
#   - save_checkpoint steps (int): 모델 저장 주기
#
#   - world_size (int): GPU 개수
#   - visible_gpus (str): GPU 번호
#   - gpu_ranks (str): GPU 번호
#   - seed (int): (default=666)
#
#   - accum_count (int): (default=2)
#   - report_every (int): (default=50)
#   - recall_eval (bool): (default=false)
#   - report_rouge (bool): (default=false)
#   - block_trigram (bool): (default=true)

# %%
# !nvidia-smi
# Out:
# Sat May 27 10:46:39 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A100-SXM...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   32C    P0    45W / 400W |      0MiB / 40960MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# #### Classifier

# %%
logdirlocation = '/content/drive/MyDrive/Gachon_University/2023-1/DeepLearning/ActiveLearning/extractive_summary/LOG/KLUE'
os.makedirs(logdirlocation, exist_ok=True)

# !python /content/SRC/train.py \
  -mode train \
  -encoder classifier \
  -dropout 0.1 \
  -bert_data_path /content/drive/MyDrive/Gachon_University/2023-1/DeepLearning/ActiveLearning/extractive_summary/DATA/KLUE/bert_data/train/korean \
  -model_path /content/drive/MyDrive/Gachon_University/2023-1/DeepLearning/ActiveLearning/extractive_summary/MODEL/KLUE/bert_classifier \
  -lr 2e-3 \
  -visible_gpus 0 \
  -gpu_ranks 0 \
  -world_size 1 \
  -report_every 1000\
  -save_checkpoint_steps 100 \
  -batch_size 1000 \
  -decay_method noam \
  -train_steps 1000 \
  -accum_count 2 \
  -log_file /content/drive/MyDrive/Gachon_University/2023-1/DeepLearning/ActiveLearning/extractive_summary/LOG/KLUE/bert_classifier.txt \
  -use_interval true \
  -warmup_steps 200

# %% [markdown]
# #### RNN

# %%
logdirlocation = '/content/drive/MyDrive/Gachon_University/2023-1/DeepLearning/ActiveLearning/extractive_summary/LOG/KLUE'
os.makedirs(logdirlocation, exist_ok=True)

# !python ./SRC/train.py \
  -mode train \
  -encoder rnn \
  -dropout 0.1 \
  -bert_data_path /content/drive/MyDrive/Gachon_University/2023-1/DeepLearning/ActiveLearning/extractive_summary/DATA/KLUE/bert_data/train/korean \
  -model_path /content/drive/MyDrive/Gachon_University/2023-1/DeepLearning/ActiveLearning/extractive_summary/MODEL/KLUE/bert_rnn \
  -lr 2e-3 \
  -visible_gpus 0 \
  -gpu_ranks 0 \
  -world_size 1 \
  -report_every 1000\
  -save_checkpoint_steps 100 \
  -batch_size 1000 \
  -decay_method noam \
  -train_steps 1000 \
  -accum_count 2 \
  -log_file /content/drive/MyDrive/Gachon_University/2023-1/DeepLearning/ActiveLearning/extractive_summary/LOG/KLUE/bert_rnn.txt \
  -use_interval true \
  -warmup_steps 200 \
  -rnn_size 768

# %% [markdown]
# #### Transformer

# %%
logdirlocation = '/content/drive/MyDrive/Gachon_University/2023-1/DeepLearning/ActiveLearning/extractive_summary/LOG/KLUE'
os.makedirs(logdirlocation, exist_ok=True)

# !python /content/SRC/train.py \
  -mode train \
  -encoder transformer \
  -dropout 0.1 \
  -bert_data_path /content/drive/MyDrive/Gachon_University/2023-1/DeepLearning/ActiveLearning/extractive_summary/DATA/KLUE/bert_data/train/korean \
  -model_path /content/drive/MyDrive/Gachon_University/2023-1/DeepLearning/ActiveLearning/extractive_summary/MODEL/KLUE/bert_transformer \
  -lr 2e-3 \
  -visible_gpus 0 \
  -gpu_ranks 0 \
  -world_size 1 \
  -report_every 1000\
  -save_checkpoint_steps 10000 \
  -batch_size 1000 \
  -decay_method noam \
  -train_steps 20000 \
  -accum_count 2 \
  -log_file /content/drive/MyDrive/Gachon_University/2023-1/DeepLearning/ActiveLearning/extractive_summary/LOG/KLUE/bert_transformer.txt \
  -use_interval true \
  -warmup_steps 200 \
  -ff_size 2048 \
  -inter_layers 2 \
  -heads 8
# Out:
# [2023-05-27 11:42:12,231 INFO] Device ID 0
# [2023-05-27 11:42:12,232 INFO] Device cuda
# Some weights of the model checkpoint at klue/bert-base were not used when initializing BertModel: ['cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.decoder.bias', 'cls.seq_relationship.weight', 'cls.predictions.bias', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %% [markdown]
# ## Test

# %% [markdown]
# ### Classifier

# %%
logdirlocation = '/content/drive/MyDrive/Gachon_University/2023-1/DeepLearning/ActiveLearning/extractive_summary/LOG/KLUE'
os.makedirs(logdirlocation, exist_ok=True)

resdirlocation = '/content/drive/MyDrive/Gachon_University/2023-1/DeepLearning/ActiveLearning/extractive_summary/RESULT'
os.makedirs(resdirlocation, exist_ok=True)

tmpdirlocation = '/content/drive/MyDrive/Gachon_University/2023-1/DeepLearning/ActiveLearning/extractive_summary/TEMP'
os.makedirs(tmpdirlocation, exist_ok=True)


# !python ./SRC/train.py \
  -mode test \
  -bert_data_path /content/drive/MyDrive/Gachon_University/2023-1/DeepLearning/ActiveLearning/extractive_summary/DATA/KLUE/bert_data/valid/korean \
  -model_path /content/drive/MyDrive/Gachon_University/2023-1/DeepLearning/ActiveLearning/extractive_summary/MODEL/KLUE/bert_classifier \
  -result_path /content/drive/MyDrive/Gachon_University/2023-1/DeepLearning/ActiveLearning/extractive_summary/RESULT/ \
  -temp_dir /content/drive/MyDrive/Gachon_University/2023-1/DeepLearning/ActiveLearning/extractive_summary/TEMP/ \
  -visible_gpus 0 \
  -gpu_ranks 0 \
  -world_size 1 \
  -batch_size 30000 \
  -log_file /content/drive/MyDrive/Gachon_University/2023-1/DeepLearning/ActiveLearning/extractive_summary/LOG/KLUE/bert_classifier_test.txt \
  -test_from /content/drive/MyDrive/Gachon_University/2023-1/DeepLearning/ActiveLearning/extractive_summary/MODEL/KLUE/bert_classifier/model_step_1000.pt

# %% [markdown]
# ### RNN

# %%
logdirlocation = '/content/drive/MyDrive/Gachon_University/2023-1/DeepLearning/ActiveLearning/extractive_summary/LOG/KLUE'
os.makedirs(logdirlocation, exist_ok=True)

resdirlocation = '/content/drive/MyDrive/Gachon_University/2023-1/DeepLearning/ActiveLearning/extractive_summary/RESULT'
os.makedirs(resdirlocation, exist_ok=True)

tmpdirlocation = '/content/drive/MyDrive/Gachon_University/2023-1/DeepLearning/ActiveLearning/extractive_summary/TEMP'
os.makedirs(tmpdirlocation, exist_ok=True)

# !python ./SRC/train.py \
  -mode test \
  -bert_data_path /content/drive/MyDrive/Gachon_University/2023-1/DeepLearning/ActiveLearning/extractive_summary/DATA/KLUE/bert_data/valid/korean \
  -model_path /content/drive/MyDrive/Gachon_University/2023-1/DeepLearning/ActiveLearning/extractive_summary/MODEL/KLUE/bert_rnn \
  -result_path /content/drive/MyDrive/Gachon_University/2023-1/DeepLearning/ActiveLearning/extractive_summary/RESULT/ \
  -temp_dir /content/drive/MyDrive/Gachon_University/2023-1/DeepLearning/ActiveLearning/extractive_summary/TEMP/ \
  -visible_gpus 0 \
  -gpu_ranks 0 \
  -world_size 1 \
  -batch_size 1000 \
  -log_file /content/drive/MyDrive/Gachon_University/2023-1/DeepLearning/ActiveLearning/extractive_summary/LOG/KLUE/bert_rnn_test.txt \
  -test_from /content/drive/MyDrive/Gachon_University/2023-1/DeepLearning/ActiveLearning/extractive_summary/MODEL/KLUE/bert_rnn/model_step_1000.pt

# %% [markdown]
# ### Transformer

# %%
logdirlocation = '/content/drive/MyDrive/Gachon_University/2023-1/DeepLearning/ActiveLearning/extractive_summary/LOG/KLUE'
os.makedirs(logdirlocation, exist_ok=True)

resdirlocation = '/content/drive/MyDrive/Gachon_University/2023-1/DeepLearning/ActiveLearning/extractive_summary/RESULT'
os.makedirs(resdirlocation, exist_ok=True)

tmpdirlocation = '/content/drive/MyDrive/Gachon_University/2023-1/DeepLearning/ActiveLearning/extractive_summary/TEMP'
os.makedirs(tmpdirlocation, exist_ok=True)

# !python ./SRC/train.py \
  -mode test \
  -bert_data_path ./drive/MyDrive/Fast_Campus/ExSum/DATA/KLUE/bert_data/valid/korean \
  -model_path /content/drive/MyDrive/Gachon_University/2023-1/DeepLearning/ActiveLearning/extractive_summary/MODEL/KLUE/bert_transformer \
  -result_path /content/drive/MyDrive/Gachon_University/2023-1/DeepLearning/ActiveLearning/extractive_summary/RESULT/ \
  -temp_dir /content/drive/MyDrive/Gachon_University/2023-1/DeepLearning/ActiveLearning/extractive_summary/TEMP/ \
  -visible_gpus 0 \
  -gpu_ranks 0 \
  -world_size 1 \
  -batch_size 1000 \
  -log_file /content/drive/MyDrive/Gachon_University/2023-1/DeepLearning/ActiveLearning/extractive_summary/LOG/KLUE/bert_transformer_test.txt \
  -test_from /content/drive/MyDrive/Gachon_University/2023-1/DeepLearning/ActiveLearning/extractive_summary/MODEL/KLUE/bert_transformer/model_step_1000.pt

# %% [markdown]
# # Inference

# %%
# !python /content/SRC/train.py \
  -mode inference \
  -visible_gpus -1 \
  -gpu_ranks -1 \
  -world_size 0 \
  -log_file /content/drive/MyDrive/Gachon_University/2023-1/DeepLearning/ActiveLearning/extractive_summary/LOG/KLUE/bert_transformer_inference.txt \
  -test_from /content/drive/MyDrive/Gachon_University/2023-1/DeepLearning/ActiveLearning/extractive_summary/MODEL/KLUE/bert_transformer/model_step_20000.pt \
  -input_text /content/drive/MyDrive/Gachon_University/2023-1/DeepLearning/ActiveLearning/extractive_summary/DATA/raw_data/valid.txt
# Out:
# 김민재와 맨체스터 유나이티드가 가까워지고 있는 가운데, 아스널도 김민재 영입전에 참전했다.
#
#
#
# 김민재의 주가가 나날이 치솟고 있다. 지난 여름 1,805만 유로(약 257억 원)의 금액으로 나폴리의 유니폼을 입은 그는 적응기 없이 팀의 수비벽을 견고하게 만들었다.
#
#
#
# 새로운 역사의 주인공이 됐다. 나폴리는 김민재의 활약에 힘입어 라이벌들을 압도하며 33년 만의 스쿠데토를 차지하는 쾌거를 이뤄냈다. 또한 유럽축구연맹(UEFA) 챔피언스리그(UCL)에서도 사상 처음으로 8강에 진출하며 아름다운 시즌을 장식했다.
#
#
#
# 수많은 클럽이 김민재를 주시하고 있다. 맨유, 리버풀, 파리 생제르맹(PSG) 등 센터백 보강을 필요로 하는 구단이라면 한 번 쯤 김민재와 연결됐다. 세리에A를 호령한 센터백에게 5,000만 유로(약 713억 원)를 전후하는 바이아웃은 저렴하게 보일 정도다.
#
#
#
# 가장 깊게 엮인 팀은 맨유다. 이미 '키스 키스 나폴리', '일 마티노' 등 유수의 나폴리 현지 매체들은 맨유가 김민재와 협상을 진행하고 있으며, 김민재가 이번 여름 나폴리를 떠날 것이라 예측했다.
#
#
#
# 이유는 충분하다. 맨유는 올 시즌 라파엘 바란과 리산드로 마르티네스의 강력한 중앙수비 조합을 구축했다. 그러나 이 둘이 빠졌을 때 후방 안정화에 실패하며 굴곡을 겪기도 했다. 바란의 나이가 30세로 적지 않고 부상도 잦아지고 있어 그의 잠재적인 대체자도 필요한 상황이다.
#
#
#
# 이적 전문가도 김민재의 맨유행을 점쳤다. 유럽축구 이적시장에 정통한 파브리시오 로마노 기자는 "맨유는 김민재에게 정말로 관심이 있다. 11월부터 접촉해왔다. 하지만 맨유도 지금 바로 바이아웃을 발동할 수는 없다"라며 맨유가 7월이 되자마자 방출 조항을 통해 김민재를 데려올 것이라 내다봤다.
#
#
#
# ...
